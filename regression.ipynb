# %%
import pandas as pd
import pickle
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
df = pd.read_csv('count_1to4.csv')
df1 = pd.read_csv('smoothing_combined_data_5_to_42.csv')

# %%
models = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train = group[['TV']]
    Y_train = group[['Sales']]
    model = LinearRegression()
    model.fit(X_train, Y_train)
    models[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train = group[['TV']]
    Y_train = group[['Sales']]
    model = LinearRegression()
    model.fit(X_train, Y_train)
    models[advertiser] = model
pickle.dump(models, open('linear_regression_model.pkl', 'wb'))

# %%
models = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train = group[['TV', 'Print Media', 'RADIO']]
    Y_train = group[['Sales']]
    model = LinearRegression()
    model.fit(X_train, Y_train)
    models[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train = group[['TV', 'Print Media', 'RADIO']]
    Y_train = group[['Sales']]
    model = LinearRegression()
    model.fit(X_train, Y_train)
    models[advertiser] = model
pickle.dump(models, open('multiple_regression_TV_Radio_Media.pkl', 'wb'))

# %%
models = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train = group[['TV', 'Print Media', 'RADIO', 'GOOGLE', 'FB & Insta', 'YOUTUBE' ,'HOARDINGS', 'OTHERS']]
    Y_train = group[['Sales']]
    model = LinearRegression()
    model.fit(X_train, Y_train)
    models[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train = group[['TV', 'Print Media', 'RADIO', 'GOOGLE', 'FB & Insta', 'YOUTUBE' ,'HOARDINGS', 'OTHERS']]
    Y_train = group[['Sales']]
    model = LinearRegression()
    model.fit(X_train, Y_train)
    models[advertiser] = model
pickle.dump(models, open('multiple_regression.pkl', 'wb'))

# %%
models_TV = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_TV = group[['TV']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_TV = poly_features.fit_transform(X_train_TV)
    model.fit(X_train_poly_TV, Y_train_Sales)
    models_TV[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_TV = group[['TV']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_TV = poly_features.fit_transform(X_train_TV)
    model.fit(X_train_poly_TV, Y_train_Sales)
    models_TV[advertiser] = model

models_Print = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_Print = group[['Print Media']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Print = poly_features.fit_transform(X_train_Print)
    model.fit(X_train_poly_Print, Y_train_Sales)
    models_Print[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_Print = group[['Print Media']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Print = poly_features.fit_transform(X_train_Print)
    model.fit(X_train_poly_Print, Y_train_Sales)
    models_Print[advertiser] = model

models_Radio = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_Radio = group[['RADIO']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Radio = poly_features.fit_transform(X_train_Radio)
    model.fit(X_train_poly_Radio, Y_train_Sales)
    models_Radio[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_Radio = group[['RADIO']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Radio = poly_features.fit_transform(X_train_Radio)
    model.fit(X_train_poly_Radio, Y_train_Sales)
    models_Radio[advertiser] = model

models_Google = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_Google = group[['GOOGLE']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Google = poly_features.fit_transform(X_train_Google)
    model.fit(X_train_poly_Google, Y_train_Sales)
    models_Google[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_Google = group[['GOOGLE']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Google = poly_features.fit_transform(X_train_Google)
    model.fit(X_train_poly_Google, Y_train_Sales)
    models_Google[advertiser] = model

models_Insta = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_Insta = group[['FB & Insta']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Insta = poly_features.fit_transform(X_train_Insta)
    model.fit(X_train_poly_Insta, Y_train_Sales)
    models_Insta[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_Insta = group[['FB & Insta']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Insta = poly_features.fit_transform(X_train_Insta)
    model.fit(X_train_poly_Insta, Y_train_Sales)
    models_Insta[advertiser] = model

models_Youtube = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_Youtube = group[['YOUTUBE']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Youtube = poly_features.fit_transform(X_train_Youtube)
    model.fit(X_train_poly_Youtube, Y_train_Sales)
    models_Youtube[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_Youtube = group[['YOUTUBE']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Youtube = poly_features.fit_transform(X_train_Youtube)
    model.fit(X_train_poly_Youtube, Y_train_Sales)
    models_Youtube[advertiser] = model

models_Hoarding = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_Hoarding = group[['HOARDINGS']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Hoarding = poly_features.fit_transform(X_train_Hoarding)
    model.fit(X_train_poly_Hoarding, Y_train_Sales)
    models_Hoarding[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_Hoarding = group[['HOARDINGS']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Hoarding = poly_features.fit_transform(X_train_Hoarding)
    model.fit(X_train_poly_Hoarding, Y_train_Sales)
    models_Hoarding[advertiser] = model
   
models_Other = {}
groups = df.groupby('advertiser')
for advertiser, group in groups:
    X_train_Other = group[['OTHERS']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Other= poly_features.fit_transform(X_train_Other)
    model.fit(X_train_poly_Other, Y_train_Sales)
    models_Other[advertiser] = model
groups = df1.groupby('advertiser')
for advertiser, group in groups:
    X_train_Other = group[['OTHERS']]
    Y_train_Sales = group[['Sales']]
    poly_features = PolynomialFeatures(degree=2)
    model = LinearRegression()
    X_train_poly_Other= poly_features.fit_transform(X_train_Other)
    model.fit(X_train_poly_Other, Y_train_Sales)
    models_Other[advertiser] = model

pickle.dump(models_TV, open('polynomial_regression_TV.pkl', 'wb'))
pickle.dump(models_Print, open('polynomial_regression_Print.pkl', 'wb'))
pickle.dump(models_Radio, open('polynomial_regression_Radio.pkl', 'wb'))
pickle.dump(models_Google, open('polynomial_regression_Google.pkl', 'wb'))
pickle.dump(models_Insta, open('polynomial_regression_Insta.pkl', 'wb'))
pickle.dump(models_Youtube, open('polynomial_regression_Youtube.pkl', 'wb'))
pickle.dump(models_Hoarding, open('polynomial_regression_Hoarding.pkl', 'wb'))
pickle.dump(models_Other, open('polynomial_regression_Other.pkl', 'wb'))
